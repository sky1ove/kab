# %%
#| hide
from kab.core import *

# %% [markdown]
# # kab
#
# > Antibody utilities built with nbdev

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install kab in Development mode

# %% [markdown]
# ```sh
# # make sure kab package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to kab
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/sky1ove/kab.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c sky1ove kab
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install kab
# ```
#
#
# [repo]: https://github.com/sky1ove/kab
# [docs]: https://sky1ove.github.io/kab/
# [pypi]: https://pypi.org/project/kab/
# [conda]: https://anaconda.org/sky1ove/kab

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/sky1ove/kab
# [docs]: https://sky1ove.github.io/kab/
# [pypi]: https://pypi.org/project/kab/
# [conda]: https://anaconda.org/sky1ove/kab

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
